# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Movie_classification.csv')

# %%
df.head(10)
# Out:
#    Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0            20.1264               59.62               0.462  36524.125
# 1            20.5462               69.14               0.531  35668.655
# 2            20.5458               69.14               0.531  39912.675
# 3            20.6474               59.36               0.542  38873.890
# 4            21.3810               59.36               0.542  39701.585
# 5            20.5970               59.36               0.542  35718.650
# 6            21.7658               70.74               0.476  33396.660
# 7            22.8910               70.74               0.476  34285.460
# 8            24.2248               70.74               0.476  31280.205
# 9            23.4008               70.74               0.476  33352.220
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# ...

# %%
df.tail()
# Out:
#      Marketing expense  Production expense  Multiplex coverage     Budget  \
# 501            21.2526               78.86               0.427  36624.115
# 502            20.9054               78.86               0.427  33996.600
# 503            21.2152               78.86               0.427  38751.680
# 504            22.1918               78.86               0.427  37740.670
# 505            20.9482               78.86               0.427  33496.650
#
#      Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 501         142.6                8.68                8.775            8.620
# 502         150.2                8.78                8.945            8.770
# 503         164.5                8.83                8.970            8.855
# 504         162.8                8.73                8.845            8.800
# 505         154.3                8.64                8.880            8.680
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Marketing expense    506 non-null    float64
#  1   Production expense   506 non-null    float64
#  2   Multiplex coverage   506 non-null    float64
#  3   Budget               506 non-null    float64
#  4   Movie_length         506 non-null    float64
#  5   Lead_ Actor_Rating   506 non-null    float64
#  6   Lead_Actress_rating  506 non-null    float64
#  7   Director_rating      506 non-null    float64
#  8   Producer_rating      506 non-null    float64
#  9   Critic_rating        506 non-null    float64
#  10  Trailer_views        506 non-null    int64
#  11  3D_available         506 non-null    object
#  12  Time_taken           494 non-null    float64
#  13  Twitter_hastags      506 non-null    float64
#  14  Genre                506 non-null    object
# ...

# %%
df.describe() #statistika deskriptif
# Out:
#        Marketing expense  Production expense  Multiplex coverage  \
# count         506.000000          506.000000          506.000000
# mean           92.270471           77.273557            0.445305
# std           172.030902           13.720706            0.115878
# min            20.126400           55.920000            0.129000
# 25%            21.640900           65.380000            0.376000
# 50%            25.130200           74.380000            0.462000
# 75%            93.541650           91.200000            0.551000
# max          1799.524000          110.480000            0.615000
#
#              Budget  Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# count    506.000000    506.000000          506.000000           506.000000
# mean   34911.144022    142.074901            8.014002             8.185613
# std     3903.038232     28.148861            1.054266             1.054290
# min    19781.355000     76.400000            3.840000             4.035000
# ...

# %%
df.describe().T #mengubah kolom menjadi baris
# Out:
#                      count           mean           std          min  \
# Marketing expense    506.0      92.270471    172.030902      20.1264
# Production expense   506.0      77.273557     13.720706      55.9200
# Multiplex coverage   506.0       0.445305      0.115878       0.1290
# Budget               506.0   34911.144022   3903.038232   19781.3550
# Movie_length         506.0     142.074901     28.148861      76.4000
# Lead_ Actor_Rating   506.0       8.014002      1.054266       3.8400
# Lead_Actress_rating  506.0       8.185613      1.054290       4.0350
# Director_rating      506.0       8.019664      1.059899       3.8400
# Producer_rating      506.0       8.190514      1.049601       4.0300
# Critic_rating        506.0       7.810870      0.659699       6.6000
# Trailer_views        506.0  449860.715415  68917.763145  212912.0000
# Time_taken           494.0     157.391498     31.295161       0.0000
# Twitter_hastags      506.0     260.832095    104.779133     201.1520
# ...

# %%
df.isna() #melihat missing value dari data
# Out:
#      Marketing expense  Production expense  Multiplex coverage  Budget  \
# 0                False               False               False   False
# 1                False               False               False   False
# 2                False               False               False   False
# 3                False               False               False   False
# 4                False               False               False   False
# ..                 ...                 ...                 ...     ...
# 501              False               False               False   False
# 502              False               False               False   False
# 503              False               False               False   False
# 504              False               False               False   False
# 505              False               False               False   False
#
#      Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# ...

# %%
df.isna().sum() #sum digunakan untuk menunjukkan total missing values
# Out:
# Marketing expense       0
# Production expense      0
# Multiplex coverage      0
# Budget                  0
# Movie_length            0
# Lead_ Actor_Rating      0
# Lead_Actress_rating     0
# Director_rating         0
# Producer_rating         0
# Critic_rating           0
# Trailer_views           0
# 3D_available            0
# Time_taken             12
# Twitter_hastags         0
# Genre                   0
# Avg_age_actors          0
# Num_multiplex           0
# Collection              0
# Start_Tech_Oscar        0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Marketing expense       0
# Production expense      0
# Multiplex coverage      0
# Budget                  0
# Movie_length            0
# Lead_ Actor_Rating      0
# Lead_Actress_rating     0
# Director_rating         0
# Producer_rating         0
# Critic_rating           0
# Trailer_views           0
# 3D_available            0
# Time_taken             12
# Twitter_hastags         0
# Genre                   0
# Avg_age_actors          0
# Num_multiplex           0
# Collection              0
# Start_Tech_Oscar        0
# dtype: int64

# %%
df.shape #melihat ukuran data (baris, kolom)
# Out:
# (506, 19)

# %%
df.dtypes #melihat tipe data
# Out:
# Marketing expense      float64
# Production expense     float64
# Multiplex coverage     float64
# Budget                 float64
# Movie_length           float64
# Lead_ Actor_Rating     float64
# Lead_Actress_rating    float64
# Director_rating        float64
# Producer_rating        float64
# Critic_rating          float64
# Trailer_views            int64
# 3D_available            object
# Time_taken             float64
# Twitter_hastags        float64
# Genre                   object
# Avg_age_actors           int64
# Num_multiplex            int64
# Collection               int64
# Start_Tech_Oscar         int64
# dtype: object

# %%
df.duplicated().sum() #melihat apakah ada data yang terduplicate
# Out:
# 0

# %%
(df.isna().sum()/len(df))*100 #presentase missing values
# Out:
# Marketing expense      0.000000
# Production expense     0.000000
# Multiplex coverage     0.000000
# Budget                 0.000000
# Movie_length           0.000000
# Lead_ Actor_Rating     0.000000
# Lead_Actress_rating    0.000000
# Director_rating        0.000000
# Producer_rating        0.000000
# Critic_rating          0.000000
# Trailer_views          0.000000
# 3D_available           0.000000
# Time_taken             2.371542
# Twitter_hastags        0.000000
# Genre                  0.000000
# Avg_age_actors         0.000000
# Num_multiplex          0.000000
# Collection             0.000000
# Start_Tech_Oscar       0.000000
# dtype: float64

# %%
a = df.copy(deep=True)

# %%
a.dropna(inplace=False) #untuk menghilangkan missing value tetapi ketika di sum tidak 0
# Out:
#      Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0              20.1264               59.62               0.462  36524.125
# 1              20.5462               69.14               0.531  35668.655
# 2              20.5458               69.14               0.531  39912.675
# 3              20.6474               59.36               0.542  38873.890
# 4              21.3810               59.36               0.542  39701.585
# ..                 ...                 ...                 ...        ...
# 501            21.2526               78.86               0.427  36624.115
# 502            20.9054               78.86               0.427  33996.600
# 503            21.2152               78.86               0.427  38751.680
# 504            22.1918               78.86               0.427  37740.670
# 505            20.9482               78.86               0.427  33496.650
#
#      Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# ...

# %%
df.isna().sum()
# Out:
# Marketing expense       0
# Production expense      0
# Multiplex coverage      0
# Budget                  0
# Movie_length            0
# Lead_ Actor_Rating      0
# Lead_Actress_rating     0
# Director_rating         0
# Producer_rating         0
# Critic_rating           0
# Trailer_views           0
# 3D_available            0
# Time_taken             12
# Twitter_hastags         0
# Genre                   0
# Avg_age_actors          0
# Num_multiplex           0
# Collection              0
# Start_Tech_Oscar        0
# dtype: int64

# %%
a.dropna(inplace=True)

# %%
a
# Out:
#      Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0              20.1264               59.62               0.462  36524.125
# 1              20.5462               69.14               0.531  35668.655
# 2              20.5458               69.14               0.531  39912.675
# 3              20.6474               59.36               0.542  38873.890
# 4              21.3810               59.36               0.542  39701.585
# ..                 ...                 ...                 ...        ...
# 501            21.2526               78.86               0.427  36624.115
# 502            20.9054               78.86               0.427  33996.600
# 503            21.2152               78.86               0.427  38751.680
# 504            22.1918               78.86               0.427  37740.670
# 505            20.9482               78.86               0.427  33496.650
#
#      Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# ...

# %%
df = df.dropna() #menghilangkan missing value dan pada sum menjadi 0

# %%
df.isna().sum()
# Out:
# Marketing expense      0
# Production expense     0
# Multiplex coverage     0
# Budget                 0
# Movie_length           0
# Lead_ Actor_Rating     0
# Lead_Actress_rating    0
# Director_rating        0
# Producer_rating        0
# Critic_rating          0
# Trailer_views          0
# 3D_available           0
# Time_taken             0
# Twitter_hastags        0
# Genre                  0
# Avg_age_actors         0
# Num_multiplex          0
# Collection             0
# Start_Tech_Oscar       0
# dtype: int64

# %%
df.to_excel('Movie_classification.xlsx') #untuk mengekspor data dengan format yang berbeda

# %%
bebas = pd.read_excel('Movie_classification.xlsx')
bebas.head()
# Out:
#    Unnamed: 0  Marketing expense  Production expense  Multiplex coverage  \
# 0           0            20.1264               59.62               0.462
# 1           1            20.5462               69.14               0.531
# 2           2            20.5458               69.14               0.531
# 3           3            20.6474               59.36               0.542
# 4           4            21.3810               59.36               0.542
#
#       Budget  Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# 0  36524.125         138.7               7.825                8.095
# 1  35668.655         152.4               7.505                7.650
# 2  39912.675         134.6               7.485                7.570
# 3  38873.890         119.3               6.895                7.035
# 4  39701.585         127.7               6.920                7.070
#
#    Director_rating  Producer_rating  Critic_rating  Trailer_views  \
# ...

# %%
df.to_excel('Movie_classification_clean.xlsx', index=False)

# %%
bebas2 = pd.read_excel('Movie_classification_clean.xlsx')
bebas2.head()
# Out:
#    Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0            20.1264               59.62               0.462  36524.125
# 1            20.5462               69.14               0.531  35668.655
# 2            20.5458               69.14               0.531  39912.675
# 3            20.6474               59.36               0.542  38873.890
# 4            21.3810               59.36               0.542  39701.585
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# 1         152.4               7.505                7.650            7.440
# 2         134.6               7.485                7.570            7.495
# 3         119.3               6.895                7.035            6.920
# 4         127.7               6.920                7.070            6.815
#
#    Producer_rating  Critic_rating  Trailer_views 3D_available  Time_taken  \
# ...

# %%
import pandas as pd
iris_filename = 'Iris.csv'
iris = pd.read_csv(iris_filename, sep=',',
                   decimal='.', header = None,
                   names = ['sepal_length',
                            'sepal_width',
                            'petal_length',
                            'petal_width',
                            'target'])

# %%
iris.head()
# Out:
#      sepal_length   sepal_width   petal_length   petal_width       target
# Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 1            5.10          3.50           1.40          0.20  Iris-setosa
# 2            4.90          3.00           1.40          0.20  Iris-setosa
# 3            4.70          3.20           1.30          0.20  Iris-setosa
# 4            4.60          3.10           1.50          0.20  Iris-setosa

# %%
iris.tail()
# Out:
#     sepal_length sepal_width petal_length petal_width          target
# 146         6.70        3.00         5.20        2.30  Iris-virginica
# 147         6.30        2.50         5.00        1.90  Iris-virginica
# 148         6.50        3.00         5.20        2.00  Iris-virginica
# 149         6.20        3.40         5.40        2.30  Iris-virginica
# 150         5.90        3.00         5.10        1.80  Iris-virginica

# %%
iris.columns #untuk mengetahui nama kolom
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'target'], dtype='object')

# %%
iris['target'] #untuk menampilkan kolom yang diinginkan
# Out:
# Id            Species
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# 150    Iris-virginica
# Name: target, Length: 151, dtype: object

# %%
iris.target
# Out:
# Id            Species
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# 150    Iris-virginica
# Name: target, Length: 151, dtype: object

# %%
iris.set_index('target', inplace=True) #mengatur kolom "target" sebagai indeks/ mengubah kolom "target" menjadi indeks dari data iris
print(iris.head())
# Out:
#               sepal_length   sepal_width   petal_length   petal_width
# target
# Species      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Iris-setosa           5.10          3.50           1.40          0.20
# Iris-setosa           4.90          3.00           1.40          0.20
# Iris-setosa           4.70          3.20           1.30          0.20
# Iris-setosa           4.60          3.10           1.50          0.20

# %%
iris.reset_index(drop=True, inplace=True) #menghapus indeks yang sudah dibuat

# %%
iris
# Out:
#       sepal_length   sepal_width   petal_length   petal_width
# 0    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 1             5.10          3.50           1.40          0.20
# 2             4.90          3.00           1.40          0.20
# 3             4.70          3.20           1.30          0.20
# 4             4.60          3.10           1.50          0.20
# ..             ...           ...            ...           ...
# 146           6.70          3.00           5.20          2.30
# 147           6.30          2.50           5.00          1.90
# 148           6.50          3.00           5.20          2.00
# 149           6.20          3.40           5.40          2.30
# 150           5.90          3.00           5.10          1.80
#
# [151 rows x 4 columns]

# %%
iris_filename = 'Iris.csv'
iris = pd.read_csv(iris_filename)

# %%
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
iris['sepal_ratio'] = iris['SepalLengthCm'] / iris['SepalWidthCm'] #menghitung perbandingan antara panjang dan lebar sepal untuk setiap target
print(iris.head())
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
#    sepal_ratio
# 0     1.457143
# 1     1.633333
# 2     1.468750
# 3     1.483871
# 4     1.388889

# %%
iris['petal_area'] = iris.apply(lambda row: row['PetalLengthCm'] * row['PetalWidthCm'], axis=1) #mnggunakan .apply() untuk operasi kustom hitung luas petal (panjang X lebar)
print(iris.head())
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
#    sepal_ratio  petal_area
# 0     1.457143        0.28
# 1     1.633333        0.28
# 2     1.468750        0.26
# 3     1.483871        0.30
# 4     1.388889        0.28

# %%
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species  sepal_ratio  petal_area
# 0       Iris-setosa     1.457143        0.28
# 1       Iris-setosa     1.633333        0.28
# ...
